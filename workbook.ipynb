# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

maindf=pd.read_csv('../Data/IPIP-FFM-data-8Nov2018/data-final.csv',sep='\t')

# %%
maindf.head()
# Out:
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4   3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
#
#               dateload  screenw  screenh  introelapse  testelapse  endelapse  \
# 0  2016-03-03 02:01:01    768.0   1024.0          9.0       234.0          6
# 1  2016-03-03 02:01:20   1360.0    768.0         12.0       179.0         11
# 2  2016-03-03 02:01:56   1366.0    768.0          3.0       186.0          7
# 3  2016-03-03 02:02:02   1920.0   1200.0        186.0       219.0          7
# 4  2016-03-03 02:02:57   1366.0    768.0          8.0       315.0         17
#
#    IPC  country  lat_appx_lots_of_err  long_appx_lots_of_err
# ...

# %%
maindf.describe()
# Out:
#                EXT1          EXT2          EXT3          EXT4          EXT5  \
# count  1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06
# mean   2.648067e+00  2.773115e+00  3.288349e+00  3.140595e+00  3.276960e+00
# std    1.264407e+00  1.323943e+00  1.215006e+00  1.237442e+00  1.277593e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# 50%    3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00
# 75%    4.000000e+00  4.000000e+00  4.000000e+00  4.000000e+00  4.000000e+00
# max    5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
#
#                EXT6          EXT7          EXT8          EXT9         EXT10  \
# count  1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06  1.013558e+06
# mean   2.401100e+00  2.771744e+00  3.414818e+00  2.963740e+00  3.556469e+00
# ...

# %%
import matplotlib.pyplot as plt
print(maindf.columns[81])
#['EXT','EST','AGR','CSN','OPN']
# Out:
# CSN2_E

# %%
maindf[(maindf != 0).all(1)]
maindf['EXT1'].plot.hist(bins=15)


plt.show()

# %%
def make_df(df,string):
    lst=[f'{string}{i}' for i in range(1,11)]
    return df[lst]

# %%
EXTdf=make_df(maindf,'EXT')
EXTdf['Mean1']=EXTdf.mean(axis=1)
# Out:
# /home/spsabin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
maindf.columns[91]
# Out:
# 'OPN2_E'

# %%
def make_mean(df,lst,mode='base'):
    for i in lst:
        if mode=='base':
            dfv=make_df(df,i)
            df[f'Mean_{i}']=dfv.mean(axis=1)
        if mode=='time':
            dfv=make_df(df,f'{i}_E')
            df[f'Mean_{i}']=dfv.mean(axis=1)
    return df

# %%
traitlst=['EXT','EST','AGR','CSN','OPN']
make_mean(maindf,traitlst)
# Out:
#          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    3.0  ...
# 1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0    3.0  ...
# 1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0    4.0  ...
# 1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0    4.0  ...
# 1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0    4.0  ...
#
#          endelapse  IPC  country  lat_appx_lots_of_err  long_appx_lots_of_err  \
# ...

# %%
def scatter_hist(x, y, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y)

    # now determine nice limits by hand:
    binwidth = 0.25
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=bins)
    ax_histy.hist(y, bins=bins, orientation='horizontal')



left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

fig = plt.figure(figsize=(8, 8))

ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)


scatter_hist(x, y, ax, ax_histx, ax_histy)

plt.show()

# %%
maindf[['Mean_EXT','Mean_EST','Mean_AGR','Mean_CSN','Mean_OPN']]
# Out:
#          Mean_EXT  Mean_EXT  Mean_AGR  Mean_CSN  Mean_OPN
# 0             3.0       3.0       3.1       3.2       3.3
# 1             3.4       3.4       3.2       3.1       2.7
# 2             2.9       2.9       2.8       2.8       3.1
# 3             2.6       2.6       3.2       2.7       3.1
# 4             3.5       3.5       3.0       3.2       3.6
# ...           ...       ...       ...       ...       ...
# 1015336       3.2       3.2       3.6       3.1       2.9
# 1015337       3.4       3.4       3.3       2.8       3.3
# 1015338       3.3       3.3       3.5       3.3       3.6
# 1015339       2.8       2.8       3.1       3.0       3.5
# 1015340       3.1       3.1       3.4       2.8       3.5
#
# [1015341 rows x 5 columns]

# %%
countrydf=maindf['country'].value_counts()


countrydf.head(20).plot.bar()

# %%
#maindf[['Mean_EXT','Mean_EST','Mean_AGR','Mean_CSN','Mean_OPN']]
plt.style.use('ggplot')
dflst=['Mean_EXT','Mean_EST','Mean_AGR','Mean_CSN','Mean_OPN']
histlst=[maindf[i].plot.hist() for i in dflst]

# %%
import matplotlib.pyplot as plt


for i in range(1,6):
        plt.figure(figsize=(100,50))      
        plt.subplot(10,10,i)
        plt.hist(maindf[dflst[i-1]], bins=25)
        plt.title(dflst[i-1], fontsize=18)

# %%
maindf[['Mean_EST']]
# Out:
#          Mean_EST
# 0             2.4
# 1             2.1
# 2             2.6
# 3             2.7
# 4             2.3
# ...           ...
# 1015336       3.3
# 1015337       4.0
# 1015338       2.7
# 1015339       3.3
# 1015340       2.9
#
# [1015341 rows x 1 columns]

# %%
make_mean(maindf,traitlst,'time')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-b87862152102> in <module>
# ----> 1 make_mean(maindf,traitlst,'time')
#
# <ipython-input-47-bb873c2d9792> in make_mean(df, lst, mode)
#       5             df[f'Mean_{i}']=dfv.mean(axis=1)
#       6         if mode=='time':
# ----> 7             dfv=make_df(df,f'{i}_E')
#       8             df[f'Mean_{i}']=dfv.mean(axis=1)
#       9     return df
#
# <ipython-input-6-55232105800b> in make_df(df, string)
#       1 def make_df(df,string):
#       2     lst=[f'{string}{i}' for i in range(1,11)]
# ----> 3     return df[lst]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
# ...

# %%
dfTlst_T=['MeanT_EXT','MeanT_EST','MeanT_AGR','MeanT_CSN','MeanT_OPN']
histlst=[maindf[i].plot.hist() for i in dflst]
